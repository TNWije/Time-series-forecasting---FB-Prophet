# %% [markdown]
# # Facebook Prophet - Time Series Analysis

# %%
#pip install pystan

# %%
#conda install -c conda-forge fbprophet

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %% [markdown]
# ### Import Data

# %%
# Import data from the excel
chicago_df_1 = pd.read_csv('Chicago_Crimes_2005_to_2007.csv', error_bad_lines=False)
chicago_df_2 = pd.read_csv('Chicago_Crimes_2008_to_2011.csv', error_bad_lines=False)
chicago_df_3 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv', error_bad_lines=False)
#skipped the bad lines
# Out:
# b'Skipping line 533719: expected 23 fields, saw 24\n'
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
# merge all the data into one frame
chicago_df = pd.concat([chicago_df_1, chicago_df_2, chicago_df_3], ignore_index=False, axis=0)

# %%
chicago_df.head(5)
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0           0  4673626    HM274058  04/02/2006 01:00:00 PM
# 1           1  4673627    HM202199  02/26/2006 01:40:48 PM
# 2           2  4673628    HM113861  01/08/2006 11:16:00 PM
# 3           4  4673629    HM274049  04/05/2006 06:45:00 PM
# 4           5  4673630    HM187120  02/17/2006 09:03:14 PM
#
#                  Block  IUCR   Primary Type                   Description  \
# 0    055XX N MANGO AVE  2825  OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1   065XX S RHODES AVE  2017      NARCOTICS            MANU/DELIVER:CRACK
# 2      013XX E 69TH ST  051A        ASSAULT           AGGRAVATED: HANDGUN
# 3  061XX W NEWPORT AVE  0460        BATTERY                        SIMPLE
# 4      037XX W 60TH ST  1811      NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False  ...  45.0            11.0        26
# ...

# %% [markdown]
# ### Data Visualizatioin

# %%
# How many nulls are in the data
plt.figure(figsize = (10,10))
sns.heatmap(chicago_df.isnull(),cbar = False, cmap = 'YlGnBu')

# %%
# Dropping the unwanted columns
chicago_df.drop(['Unnamed: 0', 'Case Number', 'Case Number', 'IUCR', 'X Coordinate', 'Y Coordinate','Updated On','Year', 'FBI Code', 'Beat','Ward','Community Area', 'Location', 'District', 'Latitude' , 'Longitude'], inplace = True, axis = 1)

# %%
chicago_df
# Out:
#                ID                    Date                 Block  \
# 0         4673626  04/02/2006 01:00:00 PM     055XX N MANGO AVE
# 1         4673627  02/26/2006 01:40:48 PM    065XX S RHODES AVE
# 2         4673628  01/08/2006 11:16:00 PM       013XX E 69TH ST
# 3         4673629  04/05/2006 06:45:00 PM   061XX W NEWPORT AVE
# 4         4673630  02/17/2006 09:03:14 PM       037XX W 60TH ST
# ...           ...                     ...                   ...
# 1456709  10508679  05/03/2016 11:33:00 PM       026XX W 23RD PL
# 1456710  10508680  05/03/2016 11:30:00 PM   073XX S HARVARD AVE
# 1456711  10508681  05/03/2016 12:15:00 AM       024XX W 63RD ST
# 1456712  10508690  05/03/2016 09:07:00 PM  082XX S EXCHANGE AVE
# 1456713  10508692  05/03/2016 11:38:00 PM       001XX E 75TH ST
#
#             Primary Type                   Description  \
# 0          OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1              NARCOTICS            MANU/DELIVER:CRACK
# ...

# %%
# change the date time type
chicago_df.Date = pd.to_datetime(chicago_df.Date, format = '%m/%d/%Y %I:%M:%S %p')

# %%
# change index to datetime 
chicago_df.index = pd.DatetimeIndex(chicago_df.Date)

# %%
chicago_df
# Out:
#                            ID                Date                 Block  \
# Date
# 2006-04-02 13:00:00   4673626 2006-04-02 13:00:00     055XX N MANGO AVE
# 2006-02-26 13:40:48   4673627 2006-02-26 13:40:48    065XX S RHODES AVE
# 2006-01-08 23:16:00   4673628 2006-01-08 23:16:00       013XX E 69TH ST
# 2006-04-05 18:45:00   4673629 2006-04-05 18:45:00   061XX W NEWPORT AVE
# 2006-02-17 21:03:14   4673630 2006-02-17 21:03:14       037XX W 60TH ST
# ...                       ...                 ...                   ...
# 2016-05-03 23:33:00  10508679 2016-05-03 23:33:00       026XX W 23RD PL
# 2016-05-03 23:30:00  10508680 2016-05-03 23:30:00   073XX S HARVARD AVE
# 2016-05-03 00:15:00  10508681 2016-05-03 00:15:00       024XX W 63RD ST
# 2016-05-03 21:07:00  10508690 2016-05-03 21:07:00  082XX S EXCHANGE AVE
# 2016-05-03 23:38:00  10508692 2016-05-03 23:38:00       001XX E 75TH ST
#
#                         Primary Type                   Description  \
# Date
# ...

# %%
#count of values in the variable
chicago_df['Primary Type'].value_counts()
# Out:
# THEFT                                1245111
# BATTERY                              1079178
# CRIMINAL DAMAGE                       702702
# NARCOTICS                             674831
# BURGLARY                              369056
# OTHER OFFENSE                         368169
# ASSAULT                               360244
# MOTOR VEHICLE THEFT                   271624
# ROBBERY                               229467
# DECEPTIVE PRACTICE                    225180
# CRIMINAL TRESPASS                     171596
# PROSTITUTION                           60735
# WEAPONS VIOLATION                      60335
# PUBLIC PEACE VIOLATION                 48403
# OFFENSE INVOLVING CHILDREN             40260
# CRIM SEXUAL ASSAULT                    22789
# SEX OFFENSE                            20172
# GAMBLING                               14755
# INTERFERENCE WITH PUBLIC OFFICER       14009
# LIQUOR LAW VIOLATION                   12129
# ARSON                                   9269
# ...

# %%
# top 20 cases
order_data = chicago_df['Primary Type'].value_counts().iloc[:20].index

# %%
#plot the top 20 cases and visualize them
plt.figure(figsize = (20,10))
sns.countplot(y='Primary Type', data=chicago_df, order = order_data)

# %%
plt.figure(figsize = (20,10))
sns.countplot(y='Location Description', data=chicago_df, order=chicago_df['Location Description'].value_counts().iloc[:20].index)

# %%
# how many crimes happend in each specific year
chicago_df.resample('Y').size()
# Out:
# Date
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: A-DEC, dtype: int64

# %%
# visualizing the number of crimes per year

plt.plot(chicago_df.resample('Y').size())
plt.title('Crime count per Year')
plt.xlabel('Years')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
# visualizing the number of crimes per Month

plt.plot(chicago_df.resample('M').size())
plt.title('Crime count per Month')
plt.xlabel('Months')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
# visualizing the number of crimes per Quater

plt.plot(chicago_df.resample('Q').size())
plt.title('Crime count per Quater')
plt.xlabel('Quater')
plt.ylabel('Number of Crimes')
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# ### Data Preperation

# %%
chicago_prophet = chicago_df.resample('M').size().reset_index()
chicago_prophet
# Out:
#           Date      0
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet.columns = ['Date','Crime Count']
chicago_prophet
# Out:
#           Date  Crime Count
# 0   2005-01-31        33983
# 1   2005-02-28        32042
# 2   2005-03-31        36970
# 3   2005-04-30        38963
# 4   2005-05-31        40572
# ..         ...          ...
# 140 2016-09-30        23235
# 141 2016-10-31        23314
# 142 2016-11-30        21140
# 143 2016-12-31        19580
# 144 2017-01-31        11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet_df_final = chicago_prophet.rename(columns = {'Date':'ds', 'Crime Count':'y'})
chicago_prophet_df_final
# Out:
#             ds      y
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
m = Prophet()
m.fit(chicago_prophet_df_final)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods = 365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  60379.720403  39363.811995  71606.987410  60379.720403
# 1   2005-02-28  60249.704311  34215.264288  67336.054933  60249.704311
# 2   2005-03-31  60105.757924  41934.488936  74554.060909  60105.757924
# 3   2005-04-30  59966.454969  44400.384918  77805.147345  59966.454969
# 4   2005-05-31  59822.508582  47758.884983  81603.460878  59822.508582
# ..         ...           ...           ...           ...           ...
# 505 2018-01-27  10040.415437  -9828.232536  24479.000866   9896.468941
# 506 2018-01-28  10027.195047 -10394.273922  21608.217374   9881.604585
# 507 2018-01-29  10013.974656  -9796.369389  23237.599631   9867.821324
# 508 2018-01-30  10000.754265 -10988.775574  21569.239587   9854.102672
# 509 2018-01-31   9987.533874 -11378.838199  21127.037202   9840.391726
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
figure = m.plot(forecast, xlabel='Date', ylabel='Crime Rate')

# %%
figure3 = m.plot_components(forecast)
# what is the expected trend is looking like
# waht is the seasonality for the year
# In summer the crime rate would go up

# %%
# What would happen in next two years
future = m.make_future_dataframe(periods = 365*2)
forecast = m.predict(future) 
figure = m.plot(forecast, xlabel='Date', ylabel='Crime Rate')
figure4 = m.plot_components(forecast)
